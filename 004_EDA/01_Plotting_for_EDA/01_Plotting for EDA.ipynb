# %% [markdown]
# # Plotting for Exploratory Data Analysis(EDA)

# %% [markdown]
# # Basic Terminology

# %% [markdown]
# - What is EDA? <by>
# - Data-point/vector/Observation <by>
# - Data-set. <by>
# - Feature/Variable/Input-variable/Independent-varibale <by>
# - Label/Dependent-variable/Output-varible/Class/Class-label/Response label <by>
# - Vector: 2-D, 3-D, 4-D,....,n-D <by>
#
# Q. What is a 1-D vector: Scalar

# %% [markdown]
# # Irish Flower Dataset

# %% [markdown]
# Toy Dataset: Irish Dataset:
# __(https://en.wikipedia.org/wiki/Iris_flower_data_set#)__
# * A simple dataset to learn the basics.
# * 3 flowers of Iris species. [see images on wikipedia link above]
# * 1936 by Ronald Fisher.
# * Petal and Sepal:
# __(http://terpconnect.umd.edu/~petersd/666/html/iris_with_labels.jpg)__
# * Objective: Classify a new flower as belonging to one of the 3 classes given the 4 features.
# * Importance of domain knowledge.
# * Why use petal and sepal dimensions as features?
# * Why do we not use 'color' as a feature?

# %%
import pandas as pd 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# We have imported seaborn as sns(seaborn name space).

# %%
#Load Irish.csv into a pandas DataFrame.(https://www.kaggle.com/datasets/uciml/iris?resource=download) 
iris_flower=pd.read_csv('Iris.csv')
iris=iris_flower.T[1:].T
# We have used this(iris=iris_flower.T[1:].T) to drop the Id Column.
iris
# Out:
#     SepalLengthCm SepalWidthCm PetalLengthCm PetalWidthCm         Species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#(Q) How many data-points and features?
iris.shape
# Out:
# (150, 5)

# %%
#(Q) What are the column names in our dataset?
iris.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#(Q) How many data points for each class are present? 
#(or) How many flowers for each species are present?
iris ["Species"].value_counts ( )
# balanced-dataset vs imbalanced datasets
#Iris is a balanced dataset as the number of data points for every class is same.
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
#    # 2-D Scatter Plot

# %%
# 2-D Scatter plot :
# Always understand axis: Labels and Scale.
iris.plot(kind='scatter', x='SepalLengthCm', y='SepalWidthCm')
plt.show()

# %%
# 2-D Scatter plot with color-coding for each flower type/class.
# Here 'sns' corresponds to seaborn.
sns.set_style('whitegrid')
sns.FacetGrid(iris, hue='Species', height=5, aspect=1)\
   .map(plt.scatter, 'SepalLengthCm', 'SepalWidthCm')\
   .add_legend()
plt.show()

# %% [markdown]
# # Observation(s)

# %% [markdown]
# 1. Using SepalLengthCm and SepalWidthCm features, we can distinguish Setosa flowers from others.
# 2. Seperating Versicolor from Viginica is much harder as they have considerable overlap.

# %% [markdown]
# # 3-D Scatter Plot

# %% [markdown]
# __(https://plot.ly/pandas/3d-scatter-plots/)__ <br>
# Needs a lot to mouse interaction to interpret data.

# %% [markdown]
# # Pair Plot

# %%
# pairwise scatter plot: Pair-Plot
# Dis-advantages:
#Can be used when number of features are high.
#Cannot visualize higher dimensional patterns in 3-D and 4-D.
#Only possible to view 2D patterns.

sns.set_style('whitegrid')
sns.pairplot(iris, hue='Species', height=3)
plt.show()

# NOTE: the diagnol elements are PDFs for each feature.
# Here there are four features available in the iris dataset so there will be 4_C_2 =6 plots.

# %% [markdown]
# # Conclusions

# %% [markdown]
# 1. PetalLengthCm and PetalWidthCm are the most useful features to identify various flower types.
# 2. While Setosa can be easily identified (linearly seperable), Virnica and Versicolor have some overlap (almost linearly seperable).
# 3. We can find "lines" and "if-else" conditions to build a simple model to classify the flower types.

# %% [markdown]
# # Histogram PDF, CDF

# %%
# What about 1-D scatter plot using just one feature?
#1-D scatter plot of petal-length
import numpy as np
iris_setosa=iris.loc[iris['Species']=='Iris-setosa']
iris_virginica=iris.loc[iris['Species']=='Iris-virginica']
iris_versicolor=iris.loc[iris['Species']=='Iris-versicolor']

plt.plot(iris_setosa['PetalLengthCm'], np.zeros_like(iris_setosa['PetalLengthCm']))
plt.plot(iris_virginica['PetalLengthCm'], np.zeros_like(iris_virginica['PetalLengthCm']))
plt.plot(iris_versicolor['PetalLengthCm'], np.zeros_like(iris_versicolor['PetalLengthCm']))

# DisAdvantages of 1-D scatter plot: Very hard to make sense as points.
# are overlapping alot.
#Are there better ways of visualizing 1-D scatter plots?

# %%
# Histogram Plotting of the Species.

sns.FacetGrid(iris, hue='Species', height=5)\
   .map(sns.histplot, 'PetalLengthCm')\
   .add_legend()

plt.show()

# PDF's are the smooth histogram.

# %% [markdown]
# # Univariate Analysis using PDF

# %%
sns.FacetGrid(iris, hue='Species', height=5)\
   .map(sns.histplot, 'PetalLengthCm')\
   .add_legend()

plt.show()

# %%
sns.FacetGrid(iris, hue='Species', height=5)\
   .map(sns.histplot, 'PetalWidthCm')\
   .add_legend()

plt.show()

# %%
sns.FacetGrid(iris, hue='Species', height=5)\
   .map(sns.histplot, 'SepalLengthCm')\
   .add_legend()

plt.show()

# %%
sns.FacetGrid(iris, hue='Species', height=5)\
   .map(sns.histplot, 'SepalWidthCm')\
   .add_legend()

plt.show()

# %%
# Need for Cumulative Distribution Function (CDF)
# We can visually see what percentage of versicolor flowers have a
# petal length of less than 1.6?
# How to construct a CDF?
# How to read a CDF?

# Plot CDF of petal length

counts, bin_edges=np.histogram(iris_setosa['PetalLengthCm'], bins=10, density=True)

pdf=counts/(sum(counts))
print(pdf)
print(bin_edges)

# Compute CDF.
cdf=np.cumsum(pdf)

plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.0 1.09 1.18 1.27 1.3599999999999999 1.45 1.54 1.63 1.72 1.81 1.9]

# %%
# Plots of CDF of petal length for various types of flowers.
# Misclassification error if you use petal length only.

#Plot CDF of petal_ length

# PDF and CDF for the Setosa.
counts, bin_edges=np.histogram(iris_setosa['PetalLengthCm'], bins=10, density=True)

pdf=counts/(sum(counts))
print(pdf)
print(bin_edges)

# Compute CDF.
cdf=np.cumsum(pdf)

plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

# PDF and CDF for the Verginica.
counts, bin_edges=np.histogram(iris_virginica['PetalLengthCm'], bins=10, density=True)

pdf=counts/(sum(counts))
print(pdf)
print(bin_edges)

# Compute CDF.
cdf=np.cumsum(pdf)

plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

# PDF and CDF for the Versicolor.
counts, bin_edges=np.histogram(iris_versicolor['PetalLengthCm'], bins=10, density=True)

pdf=counts/(sum(counts))
print(pdf)
print(bin_edges)

# Compute CDF.
cdf=np.cumsum(pdf)

plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.0 1.09 1.18 1.27 1.3599999999999999 1.45 1.54 1.63 1.72 1.81 1.9]
# [0.02 0.1  0.24 0.08 0.18 0.16 0.1  0.04 0.02 0.06]
# [4.5 4.74 4.98 5.220000000000001 5.46 5.7 5.94 6.180000000000001 6.42 6.66
#  6.9]
# [0.02 0.04 0.06 0.04 0.16 0.14 0.12 0.2  0.14 0.08]
# [3.0 3.21 3.42 3.63 3.84 4.05 4.26 4.47 4.68 4.89 5.1]

# %% [markdown]
# # Mean, Variance and Standard Deviation

# %%
# Mean, Variance and Standard Deviation.

# Mean:

print('Means:')
print(np.mean(iris_setosa['PetalLengthCm']))
print(np.mean(iris_virginica['PetalLengthCm']))
print(np.mean(iris_versicolor['PetalLengthCm']),'\n')

# Mean with an outlier.
print('Mean with an outlier:')
print(np.mean(np.append(iris_setosa['PetalLengthCm'],50)),'\n')

# Standard deviation:

print('Standard Deviation:')
print(np.std(iris_setosa['PetalLengthCm']))
print(np.std(iris_virginica['PetalLengthCm']))
print(np.std(iris_versicolor['PetalLengthCm']))
# Out:
# Means:
# 1.464
# 5.552
# 4.26
#
# Mean with an outlier:
# 2.4156862745098038
#
# Standard Deviation:
# 0.17176728442867112
# 0.546347874526844
# 0.4651881339845203

# %% [markdown]
# # Median, Percentile, Quantile, IQR, MAD
# ### $\bigstar{}$ MAD : Median Absolute Deviation
# Median absolute deviation are same thing like standard deviation.<br>
# The difference is standard deviation is taken around mean and median absolute deviation is taken about median.
# ### $\bigstar{}$ IQR : Inter Quartile Range
# IQR(Inter Quartile Range) is the difference between the $75^{th}$ percentile and $25^{th}$ percentile.<br>

# %% [markdown]
# # Percentile and Quantile
#
# $50^{th}$ percentile is nothing but the median.<br>
# $x$ percentile means there are $x$ percent values that are less than $x$.<br>
# and $(100-x)$ percent values are greater than $x$.

# %%
# Median, Percentile, Quantile, IQR, MAD

print('Median:')
print(np.median(iris_setosa['PetalLengthCm']))
print(np.median(iris_virginica['PetalLengthCm']))
print(np.median(iris_versicolor['PetalLengthCm']))

# Median with an outlier

print('\nMedian with an outlier:')
print(np.median(np.append(iris_setosa['PetalLengthCm'], 50)))

# Quantiles

print('\nQuantiles:')
print(np.percentile(iris_setosa['PetalLengthCm'], np.arange(0,100,25)))
print(np.percentile(iris_virginica['PetalLengthCm'], np.arange(0,100,25)))
print(np.percentile(iris_versicolor['PetalLengthCm'], np.arange(0,100,25)))

# 90^th Percentile

print('\n90th Percentile:')
print(np.percentile(iris_setosa['PetalLengthCm'],90))
print(np.percentile(iris_virginica['PetalLengthCm'],90))
print(np.percentile(iris_versicolor['PetalLengthCm'],90))

# Median Absolute Deviation:

from statsmodels import robust
print('\nAbsolute Median Deviation:')
print(robust.mad(iris_setosa['PetalLengthCm']))
print(robust.mad(iris_virginica['PetalLengthCm']))
print(robust.mad(iris_versicolor['PetalLengthCm']))

# NOTE: Median and Median Absolute Deviation will not be corrupted by outliers.
# Out:
# Median:
# 1.5
# 5.55
# 4.35
#
# Median with an outlier:
# 1.5
#
# Quantiles:
# [1.0 1.4 1.5 1.5750000000000002]
# [4.5 5.1 5.55 5.875]
# [3.0 4.0 4.35 4.6]
#
# 90th Percentile:
# 1.7
# 6.31
# 4.8
#
# Absolute Median Deviation:
# 0.14826022185056031
# 0.6671709983275211
# 0.5189107764769602

# %% [markdown]
# # Box plot and Whiskers

# %%
# Box-plot with whiskers: another method of visualizing the 1-D scatter plot
# The Concept of median, percentile, quantile.
# How to draw the box in the box-plot?
# How to draw whiskers: no standard way Could use min and max or use other
# IOR like idea.
# NOTE: IN the plot below, a technique call inter-quartile range is used in 
# Whiskers in the plot below donot correposnd to the min and max values.
# Box-plot can be visualized as a PDF on the side-ways.

sns.boxplot(x='Species', y='PetalLengthCm', data=iris)
plt.show()

# %% [markdown]
# # Violin Plots

# %%
# A violin plot combines the benefits of the previous two plots and simplifies them.
# Denser regions of the data are fatter and sparser ones thinner in a violin plot.

data_set=pd.read_csv('Iris.csv')
sns.violinplot(x='Species', y='PetalLengthCm', data=data_set, size=8)
plt.show()

# %% [markdown]
# # Summarizing plots in english

# %% [markdown]
# • Exaplain your findings/conclusions in plain english.<br>
# • Never forget your objective (the probelm you are solving) <br>
# • Perform all of your EDA aligned with your objectives.

# %% [markdown]
# # Univariate, Bivariate and Multivariate Analysis.

# %% [markdown]
# $\textbf{Univariate Analysis:}$ Univariate analysis focuses on analyzing a single variable in isolation. It involves examining the distribution, summary statistics, and visualizations of a single variable to understand its characteristics. Common techniques used in univariate analysis include histograms, box plots, bar charts, and measures such as mean, median, and standard deviation. <br>
#
# $\textbf{Bivariate Analysis:}$ Bivariate analysis involves the analysis of two variables simultaneously to explore relationships or associations between them. It helps in understanding how changes in one variable affect the other. Bivariate analysis techniques include scatter plots, correlation analysis, contingency tables, and hypothesis testing for assessing the statistical significance of the relationship. <br>
#
# $\textbf{Multivariate Analysis:}$ Multivariate analysis deals with the simultaneous analysis of three or more variables to uncover complex relationships and patterns among them. It explores how multiple variables interact and influence each other. Multivariate analysis techniques include dimensionality reduction techniques (e.g., principal component analysis), cluster analysis, factor analysis, and regression analysis with multiple predictors.

# %% [markdown]
# # Multivariate probability density, contour plot.

# %%
#2D Density plot, contors-plot

sns.jointplot(x='PetalLengthCm', y='PetalWidthCm', data=iris_setosa, kind='kde')
plt.show()

# %% [markdown]
# # Exercise

# %% [markdown]
# 1. Download Haberman Cancer Survival dataset from Kaggle. You may have to create a Kaggle account to donwload data. (https://www.kaggle.com/gilsousa/habermans-survival-data-set)
# 2. Perform a similar alanlaysis as above on this dataset with the following sections:
# 3. High level statistics of the dataset: number of points, numer of features, number of classes, data-points per class.
# 4. Explain our objective.
# 5. Perform Univaraite analysis(PDF, CDF, Boxplot, Voilin plots) to understand which features are useful towards classification.
# 6. Perform Bi-variate analysis (scatter plots, pair-plots) to see if combinations of features are useful in classfication.
# 7. Write your observations in english as crisply and unambigously as possible. Always quantify your results.
